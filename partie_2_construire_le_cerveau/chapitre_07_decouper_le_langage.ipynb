# %% [markdown]
# # Chapitre 7 · Découper le langage
#
# Notebook du chapitre 7 de *Construire un LLM de zéro* · Partie II « Construire le cerveau ».
#
# **Comment travailler.** D'abord la leçon : tout le code du chapitre, complet et prêt à
# exécuter, dans l'ordre du livre. Lis, exécute, modifie pour voir. À la fin, la section
# **Exercices** : quatre défis à trous, du plus simple au plus costaud, validés par des
# `assert`. Tu y réécris ton tokenizer BPE de mémoire.
#
# Python pur, hors ligne : pas de GPU, pas de bibliothèque à installer, un `Counter` suffit.

# %% [markdown]
# ## Setup
#
# Pas de PyTorch aujourd'hui : BPE, c'est du comptage. Le `Counter` de la bibliothèque
# standard (un dictionnaire qui compte les occurrences) est notre seul outil.

# %%
from collections import Counter

FIN = "</w>"          # le marqueur de fin de mot, collé au bout de chaque mot

print("Prêt. Counter(['a', 'b', 'a']) ->", dict(Counter(["a", "b", "a"])))

# %% [markdown]
# ## 3. BPE : le découpage appris depuis les données
#
# Compter les paires de voisins, fusionner la plus fréquente, répéter : tout BPE tient en
# quatre fonctions courtes, en Python pur. On les construit sur un corpus jouet minuscule :
# quatre verbes français à l'infinitif avec leurs fréquences. `manger` apparaît 3 fois,
# `chanter` 2 fois, `danser` 2 fois, `nager` 1 fois. Petit et déterministe : parfait pour
# vérifier chaque fonction avec des valeurs calculées à la main. (C'est le décalque du corpus
# anglais `low`/`lower`/`newest`/`widest` de l'article de Sennrich et al., 2016.)

# %%
mini_corpus = "manger manger manger chanter chanter danser danser nager"
print(dict(Counter(mini_corpus.split())))

# %% [markdown]
# ### `preparer` : fréquences et découpes de départ
#
# Deux structures nous suivront partout :
#
# - `frequences` : chaque mot distinct et son nombre d'occurrences (inutile de re-découper
#   cent fois le même mot, on compte une fois et on multiplie) ;
# - `decoupes` : la découpe **courante** de chaque mot, qui démarre en caractères,
#   avec le marqueur `FIN` collé au bout.

# %%
def preparer(corpus):
    frequences = Counter(corpus.split())       # mot -> nombre d'occurrences
    decoupes = {mot: list(mot) + [FIN] for mot in frequences}
    return frequences, decoupes


frequences, decoupes = preparer(mini_corpus)
for mot, freq in frequences.items():
    print(f"{mot:8s} ×{freq} -> {decoupes[mot]}")

# %%
assert frequences["manger"] == 3 and frequences["nager"] == 1
assert decoupes["chanter"] == ["c", "h", "a", "n", "t", "e", "r", FIN]
print("preparer OK : 4 mots distincts, découpés en caractères + marqueur de fin.")

# %% [markdown]
# ### `compter_paires` : le comptage des paires
#
# Le cœur statistique de BPE. Pour chaque mot du corpus, on fait glisser une fenêtre de deux
# tokens voisins (positions `i` et `i + 1`) et on crédite chaque paire de la **fréquence du
# mot** : la paire `("e", "r")` vue dans `manger` (3 occurrences) compte pour 3 d'un coup.

# %%
def compter_paires(frequences, decoupes):
    """Compte les paires de tokens voisins dans tout le corpus.

    Rend un Counter : (token_gauche, token_droit) -> nombre d'occurrences.
    """
    paires = Counter()
    for mot, freq in frequences.items():
        tokens = decoupes[mot]
        for i in range(len(tokens) - 1):
            paires[(tokens[i], tokens[i + 1])] += freq
    return paires

# %%
paires = compter_paires(frequences, decoupes)
assert paires[("e", "r")] == 8, "attendu 8 : les quatre verbes finissent par 'er'. As-tu multiplié par freq ?"
assert paires[("a", "n")] == 7, "attendu 7 : manger (×3), chanter (×2), danser (×2)."
assert paires[("g", "e")] == 4, "attendu 4 : manger (×3) et nager (×1)."
assert len(paires) == 15, f"attendu 15 paires distinctes, obtenu {len(paires)}."
meilleure = max(paires, key=paires.get)
assert meilleure == ("e", "r"), f"la plus fréquente devrait être ('e', 'r'), obtenu {meilleure}."
print("Vérification OK : 15 paires comptées, ('e', 'r') en tête avec 8 occurrences.")

# %% [markdown]
# ### `fusionner` : appliquer une fusion
#
# On parcourt la découpe de gauche à droite. Si les deux tokens sous nos yeux forment
# exactement la paire cherchée, on pousse leur collage `a + b` et on saute deux cases
# (le `i += 2` évite de re-fusionner le token fraîchement créé avec ce qui suit).
# Sinon, on recopie le token et on avance d'une case.

# %%
def fusionner(tokens, paire):
    """Remplace chaque occurrence de la paire (a, b) par le token collé a + b."""
    a, b = paire
    resultat = []
    i = 0
    while i < len(tokens):
        if i < len(tokens) - 1 and tokens[i] == a and tokens[i + 1] == b:
            resultat.append(a + b)             # les deux voisins deviennent un
            i += 2                             # on saute les deux d'un coup
        else:
            resultat.append(tokens[i])
            i += 1
    return resultat

# %%
assert fusionner(["l", "o", "w", "e", "r", FIN], ("l", "o")) == ["lo", "w", "e", "r", FIN]
assert fusionner(list("baobab") + [FIN], ("b", "a")) == ["ba", "o", "ba", "b", FIN], \
    "la paire apparaît deux fois dans baobab : les deux occurrences doivent fusionner."
assert fusionner(["lo", "w", FIN], ("x", "y")) == ["lo", "w", FIN], "paire absente : rien ne change."
print("Vérification OK : la fusion s'applique à toutes les occurrences, et à elles seules.")

# %% [markdown]
# ### `entrainer_bpe` : la boucle d'entraînement
#
# Tout assembler : compter, élire la paire la plus fréquente (`max(paires, key=paires.get)`),
# l'archiver, l'appliquer partout, recommencer. La liste `fusions` garde l'historique
# **dans l'ordre** : c'est elle qui permettra d'encoder de nouveaux textes exactement
# comme à l'entraînement.

# %%
def entrainer_bpe(corpus, nb_fusions):
    """Apprend nb_fusions fusions sur le corpus. Rend (fusions, decoupes)."""
    frequences, decoupes = preparer(corpus)
    fusions = []                               # l'historique, dans l'ordre
    for _ in range(nb_fusions):
        paires = compter_paires(frequences, decoupes)
        if not paires:                         # plus rien à fusionner
            break
        meilleure = max(paires, key=paires.get)
        fusions.append(meilleure)
        for mot in decoupes:
            decoupes[mot] = fusionner(decoupes[mot], meilleure)
    return fusions, decoupes

# %%
fusions_mini, decoupes_mini = entrainer_bpe(mini_corpus, 6)
attendu = [("e", "r"), ("er", FIN), ("a", "n"), ("g", "er</w>"), ("m", "an"), ("man", "ger</w>")]
assert fusions_mini == attendu, f"historique inattendu : {fusions_mini}"
assert decoupes_mini["manger"] == ["manger</w>"], "après 6 fusions, manger doit tenir en un seul token."
assert decoupes_mini["chanter"] == ["c", "h", "an", "t", "er</w>"]
print("Vérification OK. Historique appris sur le mini-corpus :")
for k, (a, b) in enumerate(fusions_mini, start=1):
    print(f"  {k}. {a} + {b} -> {a + b}")

# %% [markdown]
# ### `encoder_mot` : encoder un mot nouveau
#
# Pour découper un mot (même jamais vu !), on le casse en caractères puis on **rejoue
# l'historique des fusions, dans l'ordre exact de l'entraînement**. C'est ce qui garantit
# qu'un même mot est toujours découpé pareil, aujourd'hui comme demain.

# %%
def encoder_mot(mot, fusions):
    """Découpe un mot (connu ou inconnu) en tokens du vocabulaire."""
    tokens = list(mot) + [FIN]
    for paire in fusions:                      # l'ordre appris, rejoué tel quel
        tokens = fusionner(tokens, paire)
    return tokens

# %%
assert encoder_mot("manger", fusions_mini) == ["manger</w>"]
assert encoder_mot("changer", fusions_mini) == ["c", "h", "an", "ger</w>"], \
    "changer n'est PAS dans le corpus, et pourtant : quatre morceaux connus. C'est toute la magie subword."
assert encoder_mot("cadet", fusions_mini) == ["c", "a", "d", "e", "t", FIN], \
    "aucune fusion ne s'applique : retombée propre sur les caractères."
print("Vérification OK : encoder_mot('changer') ->", encoder_mot("changer", fusions_mini))

# %% [markdown]
# ## 4. Ton BPE lit les trente fables
#
# Passons au corpus du chapitre 1 : les trente fables de La Fontaine, embarquées ci-dessous
# (38 Ko, zéro téléchargement).

# %%
corpus = """\
LA CIGALE ET LA FOURMI
La cigale, ayant chanté
Tout l'été,
Se trouva fort dépourvue
Quand la bise fut venue :
Pas un seul petit morceau
De mouche ou de vermisseau.
Elle alla crier famine
Chez la fourmi, sa voisine,
La priant de lui prêter
Quelque grain pour subsister
Jusqu'à la saison nouvelle.
Je vous paierai, lui dit-elle,
Avant l'oût, foi d'animal,
Intérêt et principal.
La fourmi n'est pas prêteuse :
C'est là son moindre défaut.
Que faisiez-vous au temps chaud ?
Dit-elle à cette emprunteuse. -
Nuit et jour à tout venant
Je chantais, ne vous déplaise. -
Vous chantiez, j'en suis fort aise !
Eh bien ! dansez maintenant.


LE CORBEAU ET LE RENARD
Maître corbeau, sur un arbre perché,
Tenait en son bec un fromage.
Maître renard, par l'odeur alléché,
Lui tint à peu près ce langage :
Hé ! bonjour, monsieur du corbeau.
Que vous êtes joli ! que vous me semblez beau !
Sans mentir, si votre ramage
Se rapporte à votre plumage,
Vous êtes le phénix des hôtes de ces bois.
À ces mots le corbeau ne se sent pas de joie ;
Et, pour montrer sa belle voix,
Il ouvre un large bec, laisse tomber sa proie.
Le renard s'en saisit, et dit : Mon bon monsieur,
Apprenez que tout flatteur
Vit aux dépens de celui qui l'écoute :
Cette leçon vaut bien un fromage, sans doute.
Le corbeau, honteux et confus,
Jura, mais un peu tard, qu'on ne l'y prendrait plus.


LA GRENOUILLE QUI SE VEUT FAIRE AUSSI GROSSE QUE LE BŒUF
Une grenouille vit un bœuf
Qui lui sembla de belle taille.
Elle, qui n'était pas grosse en tout comme un œuf,
Envieuse, s'étend, et s'enfle, et se travaille
Pour égaler l'animal en grosseur ;
Disant : Regardez bien, ma sœur ;
Est-ce assez ? dites-moi ; n'y suis-je point encore ? -
Or bien, sans crier davantage,
Rapportons-nous, dit-elle, à Raminagrobis.
C'était un chat vivant comme un dévot ermite,
Un chat faisant la chattemite,
Un saint homme de chat, bien fourré, gros et gras,
Arbitre expert sur tous les cas.
Jean lapin pour juge l'agrée.
Les voilà tous deux arrivés
Devant sa majesté fourrée.
Grippeminaud leur dit : Mes enfants, approchez,
Approchez : je suis sourd, les ans en sont la cause.
L'un et l'autre approcha, ne craignant nulle chose.
Aussitôt qu'à portée il vit les contestants,
Grippeminaud le bon apôtre,
Jetant des deux côtés la griffe en même temps,
Mit les plaideurs d'accord en croquant l'un et l'autre.
Ceci ressemble fort aux débats qu'ont parfois
Les petits souverains se rapportant aux rois.


LES DEUX MULETS
Deux mulets cheminaient, l'un d'avoine chargé,
L'autre portant l'argent de la gabelle.
Celui-ci, glorieux d'une charge si belle,
N'eût voulu pour beaucoup en être soulagé.
Il marchait d'un pas relevé
Et faisait sonner sa sonnette ;
Quand l'ennemi se présentant,
Comme il en voulait à l'argent,
Sur le mulet du fisc une troupe se jette,
Le saisit au frein, et l'arrête.
Le mulet, en se défendant,
Se sent percer de coups ; il gémit, il soupire.
Est-ce donc là, dit-il, ce qu'on m'avait promis ?
Ce mulet qui me suit du danger se retire,
Et moi j'y tombe et je péris !
Ami, lui dit son camarade,
Il n'est pas toujours bon d'avoir un haut emploi :
Si tu n'avais servi qu'un meunier comme moi,
Tu ne serais pas si malade.
"""

print(f"{len(corpus)} caractères, {len(set(corpus))} caractères distincts")

# %% [markdown]
# ### 4.1 Les fusions apprises
#
# On entraîne 300 fusions et on lit la liste : elle raconte le français. D'abord les fins
# de mots les plus courantes, puis les digrammes (`ou`, `en`, `ai`, `on`), et la fusion 12,
# `qu` : personne n'a dit à l'algorithme que le « q » ne se promène presque jamais sans
# son « u ». Il a compté.

# %%
import time

debut = time.time()
fusions, decoupes = entrainer_bpe(corpus, nb_fusions=300)
print(f"300 fusions apprises en {time.time() - debut:.1f} s\n")

print("Les 15 premières fusions :")
for k, (a, b) in enumerate(fusions[:15], start=1):
    print(f"  {k:2d}. {a!r} + {b!r} -> {(a + b)!r}")

# %%
# Fréquent = token entier ; rare = morceaux réutilisables ; unique = pièces détachées.
for mot in ["loup", "renard", "grenouille", "fontaine"]:
    occurrences = corpus.lower().count(mot)
    print(f"{mot:12s} ({occurrences:2d} occurrence(s)) -> {encoder_mot(mot, fusions)}")

# %% [markdown]
# ### 4.2 Encoder et décoder : l'aller-retour complet
#
# Le vocabulaire = les caractères de départ, le marqueur de fin de mot, et un token par fusion.
# Comme au chapitre 1, une table donne un numéro à chaque token, et la table inverse permet le retour.
# Le `decoder` recolle tout puis remplace chaque marqueur par une espace. Nuance honnête : les
# retours à la ligne des vers ressortent en espaces simples ; les tokenizers de production traitent
# espaces et sauts de ligne comme des caractères à part entière, d'où leur aller-retour parfait.

# %%
vocab = sorted(set("".join(corpus.split()))) + [FIN]
for a, b in fusions:
    vocab.append(a + b)

tokens_ids = {token: i for i, token in enumerate(vocab)}
ids_tokens = {i: token for token, i in tokens_ids.items()}

def encoder(texte):
    return [tokens_ids[t] for mot in texte.split()
                          for t in encoder_mot(mot, fusions)]

def decoder(ids):
    texte = "".join(ids_tokens[i] for i in ids)
    return texte.replace(FIN, " ").strip()

assert len(vocab) == 380, f"attendu 380 tokens (79 caractères + marqueur + 300 fusions), obtenu {len(vocab)}"
print(f"Vocabulaire : {len(vocab)} tokens")

# %%
morale = "La raison du plus fort est toujours la meilleure :"
ids = encoder(morale)
print(f"{len(morale)} caractères -> {len(ids)} tokens")
print("ids     :", ids)
print("tokens  :", [ids_tokens[i] for i in ids])
print("decode  :", decoder(ids))

assert decoder(ids) == morale, "l'aller-retour doit rendre le texte intact"
assert len(ids) == 18
print("\nAller-retour parfait : texte -> numéros -> texte.")

# %%
frequences_fables = Counter(corpus.split())
cache = {mot: encoder_mot(mot, fusions) for mot in frequences_fables}

nb_tokens = sum(len(cache[mot]) * freq for mot, freq in frequences_fables.items())
nb_mots = sum(frequences_fables.values())

print(f"Corpus : {len(corpus)} caractères -> {nb_tokens} tokens BPE ({len(corpus) / nb_tokens:.1f}x plus court)")
print(f"Fenêtre de 16 cases : {16 * nb_mots / len(corpus):.1f} mots en caractères, "
      f"{16 * nb_mots / nb_tokens:.1f} mots en tokens BPE")

assert nb_tokens == 16873, f"comptage attendu 16873, obtenu {nb_tokens}"

# %% [markdown]
# ## 5. Le mot qui fait tout planter
#
# Notre filet de sécurité (« au pire, retomber sur les caractères ») ne couvre que les
# caractères **du corpus d'entraînement**. Or la lettre « w » n'apparaît dans aucune des
# trente fables. Regarde ce qui se passe, sous try/except :

# %%
try:
    encoder("Awa regarde le renard")
    print("Encodé sans erreur (surprenant !)")
except KeyError as erreur:
    print("KeyError :", erreur)
    print("Le « w » d'Awa n'existe ni dans les fables, ni dans le vocabulaire :")
    print("aucun numéro à lui donner, le tokenizer plante net.")

assert "w" not in tokens_ids, "si cet assert échoue, ton corpus contient un w inattendu"

# %% [markdown]
# ### La sortie de secours : les octets (survol)
#
# Le byte-level BPE de GPT-2 règle le problème à la racine : le vocabulaire de départ n'est plus
# « les caractères du corpus » mais **les 256 octets possibles**. Or tout texte, dans n'importe
# quelle langue, est une suite d'octets (norme UTF-8) : plus rien n'est jamais refusé.

# %%
print("« é »   en octets UTF-8 :", list("é".encode("utf-8")), "(un caractère accentué = deux octets)")
print("« Awa » en octets UTF-8 :", list("Awa".encode("utf-8")))
print("« 𝄞 »   en octets UTF-8 :", list("𝄞".encode("utf-8")), "(la clé de sol : quatre octets)")
print()
print("Chaque octet vaut entre 0 et 255 : un vocabulaire qui démarre des 256 octets")
print("peut encoder n'importe quel texte du monde. Jamais de KeyError, par construction.")

# %% [markdown]
# ## Exercices
#
# Quatre exercices, du plus simple (●) au plus costaud (●●●) : tu réécris toi-même,
# de mémoire, les quatre fonctions du tokenizer. C'est le meilleur test : si elles sortent
# de tes doigts sans regarder la leçon plus haut, BPE est à toi. Chaque cellule marquée
# `# TODO(toi)` contient un trou ; complète-le, puis exécute la cellule de validation
# (`assert`) qui suit : si elle passe sans erreur, c'est gagné.
#
# **Le pacte « IA débranchée » agit ici** : pas d'IA pour remplir les trous à ta place.
# Elle peut t'expliquer une erreur ; les doigts sur le clavier, c'est toi. Les réponses
# sont dans le notebook solution
# (`solutions/partie_2_construire_le_cerveau/chapitre_07_decouper_le_langage_solution.ipynb`),
# à n'ouvrir qu'après avoir vraiment essayé.

# %% [markdown]
# ### Exercice 1 · Compter les paires voisines — niveau ●
#
# Le cœur statistique de BPE. Pour chaque mot du corpus, fais glisser une fenêtre de deux
# tokens voisins (positions `i` et `i + 1`) et crédite chaque paire de la **fréquence du mot** :
# la paire `("e", "r")` vue dans `manger` (3 occurrences) compte pour 3 d'un coup.

# %%
frequences_ex, decoupes_ex = preparer(mini_corpus)

def compter_paires(frequences, decoupes):
    """Compte les paires de tokens voisins dans tout le corpus.

    Rend un Counter : (token_gauche, token_droit) -> nombre d'occurrences.
    """
    paires = Counter()
    # TODO(toi) : pour chaque (mot, freq) de frequences.items(),
    #   parcours les tokens voisins de decoupes[mot] (positions i et i + 1,
    #   donc range(len(tokens) - 1)) et fais paires[(tokens[i], tokens[i + 1])] += freq
    ...
    return paires

# %%
# Validation : compter les paires.
paires = compter_paires(frequences_ex, decoupes_ex)
assert paires[("e", "r")] == 8, "attendu 8 : les quatre verbes finissent par 'er'. As-tu multiplié par freq ?"
assert paires[("a", "n")] == 7, "attendu 7 : manger (×3), chanter (×2), danser (×2)."
assert paires[("g", "e")] == 4, "attendu 4 : manger (×3) et nager (×1)."
assert len(paires) == 15, f"attendu 15 paires distinctes, obtenu {len(paires)}."
meilleure = max(paires, key=paires.get)
assert meilleure == ("e", "r"), f"la plus fréquente devrait être ('e', 'r'), obtenu {meilleure}."
print("Exercice 1 validé : 15 paires comptées, ('e', 'r') en tête avec 8 occurrences.")

# %% [markdown]
# ### Exercice 2 · Appliquer une fusion — niveau ●●
#
# Fusionner la paire `(a, b)` dans une découpe : parcourir les tokens de gauche à droite ;
# si les deux tokens sous nos yeux valent exactement `(a, b)`, pousser leur collage `a + b`
# et **sauter deux cases**. Sinon, recopier le token et avancer d'une case.

# %%
def fusionner(tokens, paire):
    """Remplace chaque occurrence de la paire (a, b) par le token collé a + b."""
    a, b = paire
    resultat = []
    i = 0
    # TODO(toi) : boucle while i < len(tokens) :
    #   si tokens[i] et tokens[i + 1] valent (a, b) : ajoute a + b au resultat, i += 2
    #   sinon : recopie tokens[i], i += 1
    # (pense à vérifier i < len(tokens) - 1 avant de regarder tokens[i + 1])
    ...
    return resultat

# %%
# Validation : appliquer une fusion.
assert fusionner(["l", "o", "w", "e", "r", FIN], ("l", "o")) == ["lo", "w", "e", "r", FIN]
assert fusionner(list("baobab") + [FIN], ("b", "a")) == ["ba", "o", "ba", "b", FIN], \
    "la paire apparaît deux fois dans baobab : les deux occurrences doivent fusionner."
assert fusionner(["lo", "w", FIN], ("x", "y")) == ["lo", "w", FIN], "paire absente : rien ne change."
print("Exercice 2 validé : la fusion s'applique à toutes les occurrences, et à elles seules.")

# %% [markdown]
# ### Exercice 3 · Encoder un mot nouveau — niveau ●●
#
# Pour découper un mot (même jamais vu !), on le casse en caractères puis on **rejoue
# l'historique des fusions, dans l'ordre exact de l'entraînement**. Ta fonction `fusionner`
# de l'exercice 2 fait le travail ; `fusions_mini`, appris dans la leçon, sert de banc d'essai.

# %%
def encoder_mot(mot, fusions):
    """Découpe un mot (connu ou inconnu) en tokens du vocabulaire."""
    tokens = list(mot) + [FIN]
    # TODO(toi) : rejoue chaque fusion de la liste, DANS L'ORDRE, avec fusionner
    ...
    return tokens

# %%
# Validation : encoder un mot nouveau.
assert encoder_mot("manger", fusions_mini) == ["manger</w>"]
assert encoder_mot("changer", fusions_mini) == ["c", "h", "an", "ger</w>"], \
    "changer n'est PAS dans le corpus, et pourtant : quatre morceaux connus. C'est toute la magie subword."
assert encoder_mot("cadet", fusions_mini) == ["c", "a", "d", "e", "t", FIN], \
    "aucune fusion ne s'applique : retombée propre sur les caractères."
print("Exercice 3 validé : encoder_mot('changer') ->", encoder_mot("changer", fusions_mini))

# %% [markdown]
# ### Exercice 4 · La boucle d'entraînement BPE — niveau ●●●
#
# L'assemblage final, avec TES fonctions des exercices 1 et 2 : compter, élire la paire
# la plus fréquente, l'archiver, l'appliquer partout, recommencer. La liste `fusions`
# garde l'historique **dans l'ordre** : c'est elle qui permet d'encoder de nouveaux
# textes exactement comme à l'entraînement.

# %%
def entrainer_bpe(corpus, nb_fusions):
    """Apprend nb_fusions fusions sur le corpus. Rend (fusions, decoupes)."""
    frequences, decoupes = preparer(corpus)
    fusions = []                               # l'historique, dans l'ordre
    for _ in range(nb_fusions):
        # TODO(toi), en quatre temps :
        #   1. paires = compter_paires(frequences, decoupes)
        #   2. si paires est vide : break
        #   3. meilleure = max(paires, key=paires.get) ; ajoute-la à fusions
        #   4. applique fusionner(..., meilleure) à chaque découpe de decoupes
        ...
    return fusions, decoupes

# %%
# Validation : la boucle d'entraînement complète.
fusions_ex, decoupes_ex2 = entrainer_bpe(mini_corpus, 6)
attendu = [("e", "r"), ("er", FIN), ("a", "n"), ("g", "er</w>"), ("m", "an"), ("man", "ger</w>")]
assert fusions_ex == attendu, f"historique inattendu : {fusions_ex}"
assert decoupes_ex2["manger"] == ["manger</w>"], "après 6 fusions, manger doit tenir en un seul token."
assert decoupes_ex2["chanter"] == ["c", "h", "an", "t", "er</w>"]
print("Exercice 4 validé : ton pipeline BPE complet tourne. Historique appris :")
for k, (a, b) in enumerate(fusions_ex, start=1):
    print(f"  {k}. {a} + {b} -> {a + b}")

# %% [markdown]
# ## Et maintenant ?
#
# Quatre validations vertes : tu as réécrit ton tokenizer de mémoire. Ta machine sait
# découper : trente fables, 300 fusions, un vocabulaire de 380 morceaux, et l'aller-retour
# texte ↔ numéros. Mais un numéro de token ne dit rien de son **sens** : pour le réseau,
# « loup » n'est que l'étiquette 378. Au chapitre 8, chaque token recevra un vecteur de
# nombres appris, son embedding, et les mots proches par le sens deviendront proches
# par les nombres.
