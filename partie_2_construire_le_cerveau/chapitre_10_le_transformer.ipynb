# %% [markdown]
# # Chapitre 10 · Le Transformer : assemble ton GPT
#
# Notebook du chapitre 10 de *Construire un LLM de zéro* (Partie II « Construire le cerveau »).
#
# **Comment travailler.** D'abord la leçon : tout le code du chapitre, complet et
# exécutable de bout en bout ; lis, exécute, triture (change un hyperparamètre,
# coupe un résidu, regarde ce qui casse). À la fin, la section **Exercices** :
# sept défis à trous, du plus simple au plus costaud, validés par des `assert`.
# Les corrigés vivent dans le notebook solution.
#
# Au chapitre 9, tu as écrit la self-attention de tes mains, IA débranchée. Ici, tu
# assembles tout le reste : le multi-head attention, l'encodage positionnel, les
# connexions résiduelles, la LayerNorm, le FFN, puis le GPT complet, que tu entraînes
# sur les trente fables du chapitre 1 et que tu compares à ton MiniLM.
#
# Tout tourne sur CPU, hors ligne. L'entraînement complet du GPT prend quelques
# minutes au plus ; aucun GPU nécessaire.

# %% [markdown]
# ## Setup
#
# PyTorch pour le modèle, rien d'autre. Le modèle est minuscule : le CPU suffit
# (sur Colab, tu peux activer le GPU, mais tu ne gagneras presque rien à cette taille).

# %%
import math
import time

import torch
import torch.nn as nn
import torch.nn.functional as F

torch.manual_seed(42)
print("PyTorch", torch.__version__)

# %% [markdown]
# ## 1. Le corpus : les trente fables du chapitre 1
#
# On reprend exactement la matière première du chapitre 1 : trente fables de
# Jean de La Fontaine (domaine public, Wikisource, édition 1874), embarquées dans la
# cellule suivante. Même corpus, même tâche (prédire le caractère suivant) : la seule
# chose qui change entre MiniLM et ton GPT, c'est l'architecture. C'est ce qui rend la
# comparaison de fin de notebook honnête.

# %%
corpus = """\
LA CIGALE ET LA FOURMI
La cigale, ayant chanté
Tout l'été,
Se trouva fort dépourvue
Quand la bise fut venue :
Pas un seul petit morceau
De mouche ou de vermisseau.
Elle alla crier famine
Chez la fourmi, sa voisine,
La priant de lui prêter
Quelque grain pour subsister
Jusqu'à la saison nouvelle.
Je vous paierai, lui dit-elle,
Avant l'oût, foi d'animal,
Intérêt et principal.
La fourmi n'est pas prêteuse :
C'est là son moindre défaut.
Que faisiez-vous au temps chaud ?
Dit-elle à cette emprunteuse. -
Nuit et jour à tout venant
Je chantais, ne vous déplaise. -
Vous chantiez, j'en suis fort aise !
Eh bien ! dansez maintenant.


LE CORBEAU ET LE RENARD
Maître corbeau, sur un arbre perché,
Tenait en son bec un fromage.
Maître renard, par l'odeur alléché,
Lui tint à peu près ce langage :
Hé ! bonjour, monsieur du corbeau.
Que vous êtes joli ! que vous me semblez beau !
Sans mentir, si votre ramage
Se rapporte à votre plumage,
Vous êtes le phénix des hôtes de ces bois.
À ces mots le corbeau ne se sent pas de joie ;
Et, pour montrer sa belle voix,
Il ouvre un large bec, laisse tomber sa proie.
Le renard s'en saisit, et dit : Mon bon monsieur,
Apprenez que tout flatteur
Vit aux dépens de celui qui l'écoute :
Cette leçon vaut bien un fromage, sans doute.
Le corbeau, honteux et confus,
Jura, mais un peu tard, qu'on ne l'y prendrait plus.


LA GRENOUILLE QUI SE VEUT FAIRE AUSSI GROSSE QUE LE BŒUF
Une grenouille vit un bœuf
Qui lui sembla de belle taille.
Elle, qui n'était pas grosse en tout comme un œuf,
Grippeminaud le bon apôtre,
Jetant des deux côtés la griffe en même temps,
Mit les plaideurs d'accord en croquant l'un et l'autre.
Ceci ressemble fort aux débats qu'ont parfois
Les petits souverains se rapportant aux rois.


LES DEUX MULETS
Deux mulets cheminaient, l'un d'avoine chargé,
L'autre portant l'argent de la gabelle.
Celui-ci, glorieux d'une charge si belle,
N'eût voulu pour beaucoup en être soulagé.
Il marchait d'un pas relevé
Et faisait sonner sa sonnette ;
Quand l'ennemi se présentant,
Comme il en voulait à l'argent,
Sur le mulet du fisc une troupe se jette,
Le saisit au frein, et l'arrête.
Le mulet, en se défendant,
Se sent percer de coups ; il gémit, il soupire.
Est-ce donc là, dit-il, ce qu'on m'avait promis ?
Ce mulet qui me suit du danger se retire,
Et moi j'y tombe et je péris !
Ami, lui dit son camarade,
Il n'est pas toujours bon d'avoir un haut emploi :
Si tu n'avais servi qu'un meunier comme moi,
Tu ne serais pas si malade.
"""

print(f"{len(corpus)} caractères")
print(corpus[:236])

# %%
chars = sorted(set(corpus))              # les caractères distincts, triés
vocab_size = len(chars)
stoi = {c: i for i, c in enumerate(chars)}   # caractère -> numéro
itos = {i: c for c, i in stoi.items()}       # numéro -> caractère

data = torch.tensor([stoi[c] for c in corpus])
print(f"vocabulaire : {vocab_size} caractères | corpus : {data.shape[0]} tokens")

# %% [markdown]
# ## 2. Les données : une cible par position
#
# Nouveauté par rapport au chapitre 1 : le MiniLM prédisait UN caractère par exemple
# (le 17e, après une fenêtre de 16). Un GPT, grâce au masque causal du chapitre 9,
# prédit le caractère suivant à TOUTES les positions d'un coup. La cible `y` est donc
# simplement l'entrée `x` décalée d'un cran : à la position $t$, le modèle voit
# `x[..t]` et doit prédire `x[t+1]`.
#
# Réflexe `shape` : `x` et `y` font tous les deux `(B, T)`. Un batch de 32 séquences
# de 64 caractères, c'est 32 × 64 = 2048 exercices corrigés par étape, contre 64 pour
# le MiniLM.

# %%
block_size = 64                          # le GPT lit jusqu'à 64 caractères de contexte


def fabriquer_batch(taille=32):
    ix = torch.randint(0, len(data) - block_size - 1, (taille,))
    x = torch.stack([data[i : i + block_size] for i in ix])          # (B, T)
    y = torch.stack([data[i + 1 : i + block_size + 1] for i in ix])  # (B, T), décalé d'un cran
    return x, y


x, y = fabriquer_batch()
print("x :", x.shape, "| y :", y.shape)
print("x[0, :12] :", "".join(itos[i] for i in x[0, :12].tolist()))
print("y[0, :12] :", "".join(itos[i] for i in y[0, :12].tolist()), "  <- le même texte, décalé de 1")

# %% [markdown]
# ## 3. Le multi-head attention
#
# Une tête d'attention ne suit qu'un type de relation à la fois. On en fait tourner
# plusieurs en parallèle, chacune dans un sous-espace de dimension `d_k = d_model // n_heads`,
# puis on concatène et on mixe avec une projection `W_O`.
#
# Le point qui embrouille tout le monde, c'est le découpage en têtes : un `view` qui
# éclate `d_model` en `(n_heads, d_k)`, puis un `transpose(1, 2)` qui amène l'axe des
# têtes devant. Commence par lui.

# %% [markdown]
# ### Le découpage en têtes
#
# `(B, T, d_model)` devient `(B, n_heads, T, d_k)`. Deux gestes : `view(B, T, n_heads, d_k)`
# (on renomme le découpage, rien ne bouge en mémoire), puis `transpose(1, 2)` (l'axe des
# têtes passe devant, pour que PyTorch calcule les `B × n_heads` attentions comme un seul
# gros batch).

# %%
def decouper_en_tetes(X, n_heads):
    """(B, T, d_model) -> (B, n_heads, T, d_k), avec d_k = d_model // n_heads.

    La tête h du token t doit recevoir les colonnes [h*d_k : (h+1)*d_k] du vecteur du token t.
    """
    B, T, d_model = X.shape
    d_k = d_model // n_heads
    X = X.view(B, T, n_heads, d_k).transpose(1, 2)
    return X

# %%
X = torch.arange(2 * 3 * 8, dtype=torch.float32).view(2, 3, 8)   # valeurs 0..47, faciles à suivre
H = decouper_en_tetes(X, n_heads=2)
assert H.shape == (2, 2, 3, 4), f"shape {tuple(H.shape)} au lieu de (2, 2, 3, 4) : view puis transpose(1, 2)"
assert torch.equal(H[0, 0, 1], X[0, 1, :4]), "la tête 0 doit recevoir les 4 premières colonnes de chaque token"
assert torch.equal(H[0, 1, 2], X[0, 2, 4:]), "la tête 1 doit recevoir les 4 dernières colonnes de chaque token"
print("Découpage validé : chaque tête reçoit sa tranche de chaque token.")

# %% [markdown]
# ### Cas qui échoue : le `view` direct, silencieux et faux
#
# La tentation classique : sauter le `transpose` et écrire directement
# `view(B, n_heads, T, d_k)`. La shape de sortie est la bonne, aucun message d'erreur,
# et pourtant tout est faux : `view` ne déplace rien en mémoire, il redécoupe la suite
# de nombres dans l'ordre où elle est rangée. Résultat : des morceaux de tokens
# différents se retrouvent mélangés dans la même « tête ». Regarde.

# %%
H_ok = X.view(2, 3, 2, 4).transpose(1, 2)     # le bon geste
H_ko = X.view(2, 2, 3, 4)                     # la shape a l'air bonne... mais

print("tête 0, token 1, correct :", H_ok[0, 0, 1].tolist())    # colonnes 0..3 du token 1
print("tête 0, token 1, faux    :", H_ko[0, 0, 1].tolist())    # en fait la FIN du token 0 !
print()
print("le tenseur faux mélange les tokens :",
      torch.equal(H_ko[0, 0, 1], X[0, 0, 4:]))   # True : c'est un morceau du token 0
print("Aucune erreur levée : c'est un bug silencieux. D'où l'assert de la cellule précédente,")
print("qui vérifie les VALEURS et pas seulement la shape.")

# %% [markdown]
# ### La classe `MultiHeadAttention`
#
# Tout le chapitre 9, plus le découpage en têtes. Le forward, en cinq gestes :
#
# 1. projeter `x` en Q, K, V (trois `nn.Linear`), puis découper chacun en têtes ;
# 2. scores : `Q @ K.transpose(-2, -1) / math.sqrt(d_k)` ;
# 3. masque causal (s'il est fourni) : `-inf` sur le futur, AVANT le softmax ;
# 4. softmax ligne par ligne, puis moyenne pondérée des values ;
# 5. recoller les têtes (`transpose(1, 2).contiguous().view(B, T, d_model)`) et projeter par `W_O`.

# %%
class MultiHeadAttention(nn.Module):
    """n_heads attentions en parallèle dans des sous-espaces de dimension d_k."""

    def __init__(self, d_model, n_heads):
        super().__init__()
        assert d_model % n_heads == 0, "d_model doit être divisible par n_heads"
        self.n_heads = n_heads
        self.d_k = d_model // n_heads
        self.W_Q = nn.Linear(d_model, d_model, bias=False)
        self.W_K = nn.Linear(d_model, d_model, bias=False)
        self.W_V = nn.Linear(d_model, d_model, bias=False)
        self.W_O = nn.Linear(d_model, d_model, bias=False)   # mixe les têtes recollées

    def forward(self, x, mask=None):
        B, T, d_model = x.shape
        Q = decouper_en_tetes(self.W_Q(x), self.n_heads)      # (B, h, T, d_k)
        K = decouper_en_tetes(self.W_K(x), self.n_heads)
        V = decouper_en_tetes(self.W_V(x), self.n_heads)
        scores = Q @ K.transpose(-2, -1) / math.sqrt(self.d_k)   # (B, h, T, T)
        if mask is not None:
            scores = scores.masked_fill(mask[:T, :T] == 0, float('-inf'))
        poids = torch.softmax(scores, dim=-1)
        melange = poids @ V                                   # (B, h, T, d_k)
        out = melange.transpose(1, 2).contiguous().view(B, T, d_model)
        return self.W_O(out)

# %%
# Validation contre l'implémentation officielle de PyTorch : on copie les poids
# de nn.MultiheadAttention dans ta classe, et les sorties doivent coïncider.
torch.manual_seed(0)
d_test, h_test, T_test = 32, 4, 7

reference = nn.MultiheadAttention(d_test, h_test, bias=False, batch_first=True)
mienne = MultiHeadAttention(d_test, h_test)
with torch.no_grad():
    Wq, Wk, Wv = reference.in_proj_weight.chunk(3, dim=0)
    mienne.W_Q.weight.copy_(Wq)
    mienne.W_K.weight.copy_(Wk)
    mienne.W_V.weight.copy_(Wv)
    mienne.W_O.weight.copy_(reference.out_proj.weight)

x_test = torch.randn(2, T_test, d_test)
interdit = torch.triu(torch.ones(T_test, T_test, dtype=torch.bool), diagonal=1)
sortie_ref, _ = reference(x_test, x_test, x_test, attn_mask=interdit, need_weights=False)
sortie_mienne = mienne(x_test, mask=torch.tril(torch.ones(T_test, T_test)))

assert sortie_mienne.shape == (2, T_test, d_test), f"shape {tuple(sortie_mienne.shape)}"
assert torch.allclose(sortie_ref, sortie_mienne, atol=1e-5), (
    "ta sortie diffère de nn.MultiheadAttention : vérifie le découpage en têtes, "
    "le masque (avant le softmax !) et le recollage"
)
print("Validation réussie : ta MultiHeadAttention colle à nn.MultiheadAttention de PyTorch.")

# Au passage : la contrainte de divisibilité, vue en direct.
try:
    MultiHeadAttention(d_model=96, n_heads=5)
except AssertionError as e:
    print("MultiHeadAttention(96, 5) refuse :", e)

# %% [markdown]
# ## 4. Le problème de l'ordre : l'attention est aveugle aux positions
#
# Expérience, pas affirmation : on permute les tokens d'une séquence et on regarde la
# sortie de l'attention. Chaque sortie individuelle est identique, juste déplacée. Pour
# l'attention, « le chat mange la souris » et « la souris mange le chat » contiennent
# exactement la même information. Il faut injecter la position dans les vecteurs.

# %%
torch.manual_seed(1)
attn = MultiHeadAttention(d_model=32, n_heads=4)
sequence = torch.randn(1, 5, 32)                 # 5 tokens
melange = torch.tensor([3, 0, 4, 1, 2])          # on bat les cartes

sortie = attn(sequence)                          # sans masque : attention complète
sortie_melangee = attn(sequence[:, melange, :])

print("sortie permutée == permutation de la sortie ?",
      torch.allclose(sortie[:, melange, :], sortie_melangee, atol=1e-6))
print("L'attention ne sait pas OÙ sont les tokens : elle traite la phrase comme un sac de mots.")

# %% [markdown]
# ### Le remède : des embeddings de positions, appris
#
# Comme GPT-2 : une deuxième table `nn.Embedding`, une ligne par position (0, 1, 2, ...),
# apprise par la descente de gradient exactement comme la table des tokens. On ADDITIONNE
# le vecteur de position au vecteur du token, et la même expérience échoue : permuter
# les tokens change les sorties, l'ordre compte enfin.

# %%
torch.manual_seed(1)
table_positions = nn.Embedding(5, 32)            # un vecteur appris par position
positions = table_positions(torch.arange(5))     # (5, 32)

entree = sequence + positions                                # chaque token reçoit SA position
entree_melangee = sequence[:, melange, :] + positions        # les tokens bougent, les positions restent

sortie = attn(entree)
sortie_melangee = attn(entree_melangee)
print("avec positions, sortie permutée == permutation de la sortie ?",
      torch.allclose(sortie[:, melange, :], sortie_melangee, atol=1e-6))
print("Les positions cassent l'invariance : le modèle peut maintenant utiliser l'ordre des mots.")

# %% [markdown]
# ## 5. Le bloc Transformer : collecter, puis digérer
#
# Après l'attention (qui collecte l'information chez les voisins), chaque position passe
# dans un petit MLP du chapitre 6, le FFN, qui digère ce qui vient d'être collecté,
# position par position. On monte en dimension (× 4), une GELU, on redescend.

# %%
class FeedForward(nn.Module):
    """Le MLP du chapitre 6, appliqué à chaque position indépendamment."""

    def __init__(self, d_model, d_ff):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(d_model, d_ff),    # montée : d_model -> 4 * d_model
            nn.GELU(),                   # la non-linéarité (une ReLU adoucie)
            nn.Linear(d_ff, d_model),    # descente : retour à d_model
        )

    def forward(self, x):
        return self.net(x)


ffn = FeedForward(96, 384)
print("FFN :", sum(p.numel() for p in ffn.parameters()), "paramètres,",
      "la plus grosse pièce du bloc")

# %% [markdown]
# ### Le bloc complet (Pre-LN + résidus)
#
# Deux sous-couches, et pour chacune le même emballage : une LayerNorm AVANT
# (Pre-LN), et une connexion résiduelle qui AJOUTE la sortie à l'entrée au lieu de la
# remplacer.
#
# ```
# x = x + attention(LayerNorm(x))
# x = x + ffn(LayerNorm(x))
# ```
#
# Le `x +` est l'autoroute du gradient : sans lui, rien de profond ne s'entraîne
# (la preuve expérimentale arrive juste après).

# %%
class TransformerBlock(nn.Module):
    """L'unité qu'on empile : attention + FFN, chacun avec Pre-LN et résidu."""

    def __init__(self, d_model, n_heads, d_ff):
        super().__init__()
        self.ln1 = nn.LayerNorm(d_model)
        self.attn = MultiHeadAttention(d_model, n_heads)
        self.ln2 = nn.LayerNorm(d_model)
        self.ffn = FeedForward(d_model, d_ff)

    def forward(self, x, mask=None):
        x = x + self.attn(self.ln1(x), mask)   # collecter (et garder l'autoroute)
        x = x + self.ffn(self.ln2(x))          # digérer (idem)
        return x

# %%
torch.manual_seed(0)
bloc = TransformerBlock(d_model=96, n_heads=4, d_ff=384)
x_test = torch.randn(2, 10, 96)
masque_test = torch.tril(torch.ones(10, 10))

y_test = bloc(x_test, masque_test)
assert y_test.shape == x_test.shape, "un bloc préserve la shape : c'est ce qui permet d'empiler"
assert not torch.allclose(y_test, x_test), "le bloc doit transformer x, pas le renvoyer tel quel"

# Le test du résidu : on éteint les deux sous-couches (dernières projections à zéro).
# Si ton câblage est bien x + souscouche(LN(x)), le bloc doit laisser passer x INTACT.
# (En Post-LN, x = LN(x + souscouche(x)), il sortirait LN(x), pas x.)
with torch.no_grad():
    bloc.attn.W_O.weight.zero_()
    bloc.ffn.net[2].weight.zero_()
    bloc.ffn.net[2].bias.zero_()
assert torch.allclose(bloc(x_test, masque_test), x_test, atol=1e-6), (
    "sous-couches éteintes, le bloc doit rendre x intact : vérifie tes résidus et le Pre-LN"
)
print("Bloc validé : ton bloc transforme, préserve la shape, et l'autoroute résiduelle est en place.")

# %% [markdown]
# ### Cas qui échoue : six blocs sans stabilisateurs
#
# On empile six blocs SANS résidus ni LayerNorm (la sortie de chaque sous-couche
# remplace l'entrée), et on lance le même entraînement que pour un empilement avec
# stabilisateurs. Regarde la loss et le gradient du premier bloc : sans autoroute, le
# gradient arrive mort au bloc 1 et la loss reste scotchée. Rien ne plante, aucun
# message d'erreur : le modèle refuse juste d'apprendre. C'est le bug le plus sournois
# du deep learning.

# %%
class BlocSansStabilisateurs(nn.Module):
    """Le même bloc, SANS résidus ni LayerNorm : la sortie remplace l'entrée."""

    def __init__(self, d_model, n_heads, d_ff):
        super().__init__()
        self.attn = MultiHeadAttention(d_model, n_heads)
        self.ffn = FeedForward(d_model, d_ff)

    def forward(self, x, mask=None):
        x = self.attn(x, mask)    # pas de x + ... : l'autoroute est coupée
        x = self.ffn(x)
        return x


class PileProfonde(nn.Module):
    """Six blocs + embeddings + tête : un mini GPT jetable pour l'expérience."""

    def __init__(self, bloc_cls):
        super().__init__()
        self.tok = nn.Embedding(vocab_size, 64)
        self.pos = nn.Embedding(32, 64)
        self.blocs = nn.ModuleList([bloc_cls(64, 4, 256) for _ in range(6)])
        self.ln_f = nn.LayerNorm(64)
        self.tete = nn.Linear(64, vocab_size, bias=False)
        self.register_buffer("masque", torch.tril(torch.ones(32, 32)))

    def forward(self, x):
        h = self.tok(x) + self.pos(torch.arange(x.shape[1]))
        for bloc in self.blocs:
            h = bloc(h, self.masque)
        return self.tete(self.ln_f(h))


for nom, bloc_cls in [("SANS stabilisateurs", BlocSansStabilisateurs),
                      ("avec résidus + LayerNorm", TransformerBlock)]:
    torch.manual_seed(42)
    pile = PileProfonde(bloc_cls)
    optimiseur = torch.optim.AdamW(pile.parameters(), lr=3e-3)
    for step in range(301):
        x, y = fabriquer_batch()
        x = x[:, :32].contiguous()               # séquences courtes : l'expérience va vite
        y = y[:, :32].contiguous()
        loss = F.cross_entropy(pile(x).view(-1, vocab_size), y.view(-1))
        optimiseur.zero_grad()
        loss.backward()
        optimiseur.step()
        if step in (0, 150, 300):
            grad_bloc1 = pile.blocs[0].attn.W_Q.weight.grad.abs().mean().item()
            print(f"{nom:26s} | step {step:3d} | loss {loss.item():.2f} | grad bloc 1 : {grad_bloc1:.1e}")
    print()

# %% [markdown]
# ## 6. Le GPT complet
#
# Trois étages : les embeddings (tokens + positions, additionnés), la pile de blocs,
# et la tête de sortie (LayerNorm final, puis une projection `d_model -> vocab_size`
# qui rend un score par caractère possible, à chaque position). Le softmax du
# chapitre 5 transformera ces scores en probabilités dans la cross-entropy et dans la
# génération.
#
# Nos hyperparamètres, choisis pour tenir sur un CPU :
#
# | hyperparamètre | valeur |
# |---|---|
# | `block_size` (contexte) | 64 |
# | `d_model` | 96 |
# | `n_heads` | 4 (donc d_k = 24) |
# | `n_layers` | 2 |
# | `d_ff` | 384 (4 × d_model) |

# %%
d_model, n_heads, n_layers, d_ff = 96, 4, 2, 384


class GPT(nn.Module):
    """Embeddings + positions -> n_layers blocs -> LayerNorm -> tête de sortie."""

    def __init__(self):
        super().__init__()
        self.table_tokens = nn.Embedding(vocab_size, d_model)
        self.table_positions = nn.Embedding(block_size, d_model)
        self.blocs = nn.ModuleList(
            [TransformerBlock(d_model, n_heads, d_ff) for _ in range(n_layers)]
        )
        self.ln_final = nn.LayerNorm(d_model)
        self.tete = nn.Linear(d_model, vocab_size, bias=False)
        self.register_buffer("masque", torch.tril(torch.ones(block_size, block_size)))

    def forward(self, x):
        B, T = x.shape
        h = self.table_tokens(x) + self.table_positions(torch.arange(T))   # (B, T, d_model)
        for bloc in self.blocs:
            h = bloc(h, self.masque)                                       # shape préservée
        return self.tete(self.ln_final(h))                                 # (B, T, vocab_size)

# %%
torch.manual_seed(42)
gpt = GPT()
n_params_gpt = sum(p.numel() for p in gpt.parameters())
print(f"{n_params_gpt} paramètres (MiniLM : 91 497)")
assert n_params_gpt == 244_800, f"{n_params_gpt} paramètres au lieu de 244 800 : relis les hyperparamètres"

x, y = fabriquer_batch(taille=4)
logits = gpt(x)
assert logits.shape == (4, block_size, vocab_size), f"shape {tuple(logits.shape)} au lieu de (4, 64, 81)"

# Le test de causalité : changer le DERNIER caractère ne doit rien changer aux
# prédictions des positions précédentes (le passé ne voit pas le futur).
x2 = x.clone()
x2[:, -1] = (x2[:, -1] + 1) % vocab_size
logits2 = gpt(x2)
assert torch.allclose(logits[:, :-1], logits2[:, :-1], atol=1e-5), (
    "changer le futur change le passé : le masque causal n'est pas branché"
)
assert not torch.allclose(logits[:, -1], logits2[:, -1]), "la dernière position devrait, elle, changer"
print("GPT validé : ton GPT sort un score par caractère et par position, et respecte la causalité.")

# %% [markdown]
# ## 7. L'entraînement : le refrain, une dernière fois
#
# Prédire, mesurer l'erreur, corriger les nombres, recommencer. Exactement la boucle
# du chapitre 1 ; seuls deux détails changent : les logits sortent en `(B, T, vocab_size)`
# (une prédiction par position, pas une seule), donc on les aplatit en
# `(B*T, vocab_size)` pour la cross-entropy ; et 3 000 étapes suffisent, car chaque
# étape contient 2 048 exercices au lieu de 64.
#
# Compte environ une à trois minutes sur un CPU de portable.

# %%
optimiseur = torch.optim.AdamW(gpt.parameters(), lr=3e-3)

debut = time.time()
for step in range(3001):
    x, y = fabriquer_batch()                     # (B, T) et (B, T)
    logits = gpt(x)                              # 1. prédire         (B, T, vocab_size)
    loss = F.cross_entropy(                      # 2. mesurer l'erreur
        logits.view(-1, vocab_size),             #    aplati : (B*T, vocab_size)
        y.view(-1),                              #    aplati : (B*T,)
    )
    optimiseur.zero_grad()                       # 3. corriger les nombres
    loss.backward()
    optimiseur.step()                            # 4. recommencer
    if step % 500 == 0:
        print(f"étape {step:5d} | loss {loss.item():.2f}")
print(f"Entraînement terminé en {time.time() - debut:.0f} s")

# %%
# Validation : la loss moyenne sur 20 batchs frais doit être largement sous celle du MiniLM.
with torch.no_grad():
    pertes = []
    for _ in range(20):
        x, y = fabriquer_batch()
        pertes.append(F.cross_entropy(gpt(x).view(-1, vocab_size), y.view(-1)).item())
    loss_gpt = sum(pertes) / len(pertes)
print(f"loss moyenne du GPT : {loss_gpt:.2f}")
assert loss_gpt < 1.0, f"loss {loss_gpt:.2f} trop haute : l'entraînement n'a pas convergé (attendu < 1.0)"
print("Le GPT a appris. Reste à le comparer à l'ancien champion.")

# %% [markdown]
# ## 8. Le match : ton GPT contre le MiniLM du chapitre 1
#
# Pour que la comparaison soit honnête, on réentraîne le MiniLM ici même, avec
# exactement le code et les réglages du chapitre 1 (8 000 étapes), et on mesure sa
# loss avec le même protocole (moyenne sur 20 batchs frais).

# %%
block_size_mini = 16


class MiniLM(nn.Module):
    def __init__(self):
        super().__init__()
        self.table = nn.Embedding(vocab_size, 24)
        self.reseau = nn.Sequential(
            nn.Linear(block_size_mini * 24, 192),
            nn.Tanh(),
            nn.Linear(192, vocab_size),
        )

    def forward(self, x):
        return self.reseau(self.table(x).flatten(1))


def fabriquer_batch_mini(taille=64):
    ix = torch.randint(0, len(data) - block_size_mini - 1, (taille,))
    x = torch.stack([data[i : i + block_size_mini] for i in ix])
    y = data[ix + block_size_mini]
    return x, y


torch.manual_seed(42)
minilm = MiniLM()
n_params_mini = sum(p.numel() for p in minilm.parameters())
optimiseur = torch.optim.AdamW(minilm.parameters(), lr=1e-3)
debut = time.time()
for step in range(8001):
    x, y = fabriquer_batch_mini()
    loss = F.cross_entropy(minilm(x), y)
    optimiseur.zero_grad()
    loss.backward()
    optimiseur.step()
    if step % 2000 == 0:
        print(f"étape {step:5d} | loss {loss.item():.2f}")
print(f"MiniLM réentraîné en {time.time() - debut:.0f} s")

with torch.no_grad():
    pertes = []
    for _ in range(20):
        x, y = fabriquer_batch_mini()
        pertes.append(F.cross_entropy(minilm(x), y).item())
    loss_mini = sum(pertes) / len(pertes)

print()
print(f"MiniLM (ch. 1)  | {n_params_mini:7d} paramètres | contexte 16 | loss {loss_mini:.2f}")
print(f"Notre GPT       | {n_params_gpt:7d} paramètres | contexte 64 | loss {loss_gpt:.2f}")

# %% [markdown]
# ### La génération
#
# La même mécanique qu'au chapitre 1 : prédire des probabilités, tirer au sort,
# décaler le contexte, recommencer. Seule différence : le GPT rend un score par
# position, et seul le DERNIER pas nous intéresse pour prédire la suite
# (`logits[:, -1, :]`).

# %%
def generer(model, prompt="\n", longueur=300, temperature=0.8):
    """Écrit `longueur` caractères à la suite de `prompt`, avec le GPT."""
    model.eval()
    ctx = ([stoi["\n"]] * block_size + [stoi[c] for c in prompt])[-block_size:]
    sortie = []
    with torch.no_grad():
        for _ in range(longueur):
            logits = model(torch.tensor([ctx]))[:, -1, :]            # le dernier pas seulement
            probas = torch.softmax(logits / temperature, dim=-1)     # le softmax du chapitre 5
            i = torch.multinomial(probas, num_samples=1).item()      # tirage au sort
            sortie.append(itos[i])
            ctx = ctx[1:] + [i]                                      # on décale le contexte
    return prompt + "".join(sortie)

# %%
torch.manual_seed(7)
texte = generer(gpt, prompt="La cigale", longueur=80)
assert isinstance(texte, str) and texte.startswith("La cigale"), "le texte doit commencer par le prompt"
assert len(texte) == len("La cigale") + 80, f"longueur {len(texte)} au lieu de {len('La cigale') + 80}"
assert set(texte) <= set(chars), "tous les caractères générés doivent venir du vocabulaire"
print("Génération validée : ton GPT écrit.")

# %% [markdown]
# ### Le moment de gloire : les deux modèles, côte à côte
#
# Même prompt, même température, même corpus d'entraînement. À gauche de ta mémoire :
# la soupe de caractères du chapitre 1, avant tout entraînement. Puis le MiniLM. Puis
# ton GPT.

# %%
def generer_minilm(model, prompt="\n", longueur=400, temperature=0.8):
    """La génération du chapitre 1 (fenêtre de 16, un caractère à la fois)."""
    model.eval()
    ctx = ([stoi["\n"]] * block_size_mini + [stoi[c] for c in prompt])[-block_size_mini:]
    sortie = []
    with torch.no_grad():
        for _ in range(longueur):
            scores = model(torch.tensor([ctx]))
            probas = torch.softmax(scores / temperature, dim=-1)
            i = torch.multinomial(probas, num_samples=1).item()
            sortie.append(itos[i])
            ctx = ctx[1:] + [i]
    return prompt + "".join(sortie)


torch.manual_seed(123)
print("=== MiniLM (ch. 1), 91 497 paramètres " + "=" * 30)
print(generer_minilm(minilm, "Le loup", longueur=400))
print()
print("=== Notre GPT (ch. 10), 244 800 paramètres " + "=" * 25)
print(generer(gpt, "Le loup", longueur=400))

# %% [markdown]
# ### Top-k et top-p : tailler dans la distribution
#
# La température (chapitre 5) rend les tokens absurdes moins probables, mais ne les
# supprime jamais : il en sort un de temps en temps, et une seule absurdité casse le
# fil. La promesse du chapitre 5, tenue ici : **couper** les candidats improbables
# avant le tirage.
#
# - **top-k** : ne garder que les `k` tokens les plus probables, mettre le reste à
#   `-inf`, re-normaliser.
# - **top-p** (*nucleus sampling*) : garder le plus petit ensemble dont les
#   probabilités cumulées atteignent `p`, couper le reste.
#
# On génère sur nos fables avec le GPT qu'on vient d'entraîner, à une température
# volontairement **haute** (2.0) pour rendre le problème visible.

# %%
def generer_avance(model, prompt="\n", longueur=180, temperature=1.0,
                   top_k=None, top_p=None, greedy=False):
    """Génère avec, au choix : greedy, température seule, top-k, ou top-p."""
    model.eval()
    ctx = ([stoi["\n"]] * block_size + [stoi[c] for c in prompt])[-block_size:]
    sortie = []
    with torch.no_grad():
        for _ in range(longueur):
            logits = model(torch.tensor([ctx]))[:, -1, :]        # (1, vocab_size)
            if greedy:
                i = torch.argmax(logits, dim=-1).item()
            else:
                logits = logits / temperature
                if top_k is not None:
                    v, _ = torch.topk(logits, top_k)             # les k plus grands
                    seuil = v[:, [-1]]                           # le k-ieme score
                    logits = logits.masked_fill(logits < seuil, float("-inf"))
                if top_p is not None:
                    sl, si = torch.sort(logits, descending=True, dim=-1)
                    pr = torch.softmax(sl, dim=-1)
                    cumul = torch.cumsum(pr, dim=-1)
                    a_retirer = cumul - pr >= top_p              # au-dela du noyau
                    sl = sl.masked_fill(a_retirer, float("-inf"))
                    logits = torch.full_like(logits, float("-inf")).scatter(-1, si, sl)
                probas = torch.softmax(logits, dim=-1)           # les coupes valent 0
                i = torch.multinomial(probas, num_samples=1).item()
            sortie.append(itos[i])
            ctx = ctx[1:] + [i]
    return prompt + "".join(sortie)


prompt = "Le corbeau"
print("=== 1. GREEDY (argmax, aucun alea) " + "=" * 20)
torch.manual_seed(7)
print(generer_avance(gpt, prompt, greedy=True))
print("\n=== 2. TEMPERATURE 2.0 SEULE " + "=" * 26)
torch.manual_seed(7)
print(generer_avance(gpt, prompt, temperature=2.0))
print("\n=== 3. TEMPERATURE 2.0 + TOP-K 10 " + "=" * 21)
torch.manual_seed(7)
print(generer_avance(gpt, prompt, temperature=2.0, top_k=10))
print("\n=== 4. TEMPERATURE 2.0 + TOP-P 0.9 " + "=" * 20)
torch.manual_seed(7)
print(generer_avance(gpt, prompt, temperature=2.0, top_p=0.9))

# %% [markdown]
# Sois lucide en lisant ces sorties : le corpus ne fait que 38 Ko, et un modèle de
# 244 800 paramètres qui descend à une loss aussi basse a en partie MÉMORISÉ les
# fables ; certains vers sortent presque tels quels. Sur un vrai corpus (des dizaines
# de gigaoctets), mémoriser est impossible et le modèle est forcé de généraliser.
# C'est tout le programme de la Partie III : les données, l'échelle, et comment
# évaluer honnêtement.

# %% [markdown]
# ## Exercices
#
# À toi de jouer : sept exercices, du plus simple (●) au plus costaud (●●●). La leçon
# t'a montré chaque geste ; ici, tu les refais de mémoire. Les exercices redéfinissent
# des fonctions et des classes de la leçon : c'est voulu, et la cellule de validation
# (`assert`) qui suit chaque trou te dit aussitôt si ta version tient debout.
#
# **Le pacte « IA débranchée » agit ici** : pas d'IA pour remplir les trous à ta
# place. Elle peut t'expliquer une erreur ; les doigts sur le clavier, c'est toi.
# Les réponses sont dans le notebook solution
# (`solutions/partie_2_construire_le_cerveau/`), à n'ouvrir qu'après avoir vraiment essayé.

# %% [markdown]
# ### Exercice 1 · Le découpage en têtes — niveau ●
#
# `(B, T, d_model)` devient `(B, n_heads, T, d_k)`. Deux gestes : `view(B, T, n_heads, d_k)`
# (on renomme le découpage, rien ne bouge en mémoire), puis `transpose(1, 2)` (l'axe des
# têtes passe devant, pour que PyTorch calcule les `B × n_heads` attentions comme un seul
# gros batch). Et souviens-toi du cas qui échoue : le `view` direct a la bonne shape et
# les mauvaises valeurs.

# %%
def decouper_en_tetes(X, n_heads):
    """(B, T, d_model) -> (B, n_heads, T, d_k), avec d_k = d_model // n_heads.

    La tête h du token t doit recevoir les colonnes [h*d_k : (h+1)*d_k] du vecteur du token t.
    """
    B, T, d_model = X.shape
    d_k = d_model // n_heads
    # TODO(toi) : un .view(B, T, n_heads, d_k) puis un .transpose(1, 2)
    X = ...
    return X

# %%
X = torch.arange(2 * 3 * 8, dtype=torch.float32).view(2, 3, 8)   # valeurs 0..47, faciles à suivre
H = decouper_en_tetes(X, n_heads=2)
assert isinstance(H, torch.Tensor), "remplace le ... par ton code"
assert H.shape == (2, 2, 3, 4), f"shape {tuple(H.shape)} au lieu de (2, 2, 3, 4) : view puis transpose(1, 2)"
assert torch.equal(H[0, 0, 1], X[0, 1, :4]), "la tête 0 doit recevoir les 4 premières colonnes de chaque token"
assert torch.equal(H[0, 1, 2], X[0, 2, 4:]), "la tête 1 doit recevoir les 4 dernières colonnes de chaque token"
print("Exercice 1 validé : chaque tête reçoit sa tranche de chaque token.")

# %% [markdown]
# ### Exercice 2 · Le masque top-k — niveau ●
#
# À chaque pas de génération, top-k ne garde que les `k` tokens les plus probables et met
# tous les autres à `-inf` (probabilité exactement nulle après softmax). Refais le geste
# central sur un vecteur jouet : garde les 3 meilleurs scores, coupe le reste. Le seuil est
# `v[:, [-1]]`, le k-ième score ; une seule ligne avec `masked_fill`, et la shape ne doit
# pas changer.

# %%
logits_jouet = torch.tensor([[5.0, 4.0, 3.0, 2.0, 1.0, 0.0]])
v, _ = torch.topk(logits_jouet, 3)               # les 3 plus grands scores

# TODO(toi) : mets à float("-inf") tout score STRICTEMENT sous le 3e
#   (une ligne, avec masked_fill ; le seuil est v[:, [-1]])
logits_coupes = ...

# %%
# Validation : le masque top-k.
attendu = torch.tensor([[5.0, 4.0, 3.0, float("-inf"), float("-inf"), float("-inf")]])
assert isinstance(logits_coupes, torch.Tensor), "remplace le ... par ton code"
assert logits_coupes.shape == logits_jouet.shape, "le masque ne doit PAS changer la shape"
assert torch.equal(logits_coupes, attendu), "top-k doit garder les 3 meilleurs, couper le reste à -inf"
print("Exercice 2 validé : les recalés valent -inf, le softmax leur donnera zéro exactement.")

# %% [markdown]
# ### Exercice 3 · Le comptage de paramètres — niveau ●●
#
# Le chapitre te l'a promis : le comptage des 244 800 paramètres, tu le refais toi-même,
# à la main. Rappels : `nn.Linear(a, b, bias=False)` pèse `a × b` nombres ; avec biais,
# `a × b + b` ; `nn.Embedding(n, d)` pèse `n × d` ; `nn.LayerNorm(d)` pèse `2 × d`
# (gamma et bêta). Nos hyperparamètres : `vocab_size = 81`, `block_size = 64`,
# `d_model = 96`, `d_ff = 384`, `n_layers = 2`.

# %%
# TODO(toi) : des expressions arithmétiques (les variables ci-dessus existent déjà).
nb_attention = ...    # W_Q, W_K, W_V, W_O d'UN bloc (sans biais)
nb_ffn = ...          # les deux nn.Linear du FFN d'UN bloc (AVEC leurs biais)
nb_bloc = ...         # attention + FFN + les 2 LayerNorm du bloc
nb_total = ...        # les 2 tables d'embeddings + n_layers blocs + LayerNorm final + tête (sans biais)

# %%
# Validation : le comptage, étage par étage, puis contre le modèle réel.
assert nb_attention == 36_864, f"attention : {nb_attention} au lieu de 36 864 (4 matrices d_model x d_model)"
assert nb_ffn == 74_208, f"FFN : {nb_ffn} au lieu de 74 208 (n'oublie pas les 2 biais)"
assert nb_bloc == 111_456, f"bloc : {nb_bloc} au lieu de 111 456 (attention + FFN + 2 LayerNorm)"
assert nb_total == 244_800, f"total : {nb_total} au lieu de 244 800"
assert nb_total == sum(p.numel() for p in GPT().parameters()), "ton compte doit coller au modèle réel"
print(f"Exercice 3 validé : {nb_total} paramètres, dont {n_layers * nb_ffn} dans les FFN.")

# %% [markdown]
# ### Exercice 4 · Le bloc Transformer — niveau ●●
#
# Deux sous-couches, et pour chacune le même emballage : une LayerNorm AVANT (Pre-LN),
# et une connexion résiduelle qui AJOUTE la sortie à l'entrée au lieu de la remplacer :
#
# ```
# x = x + attention(LayerNorm(x))
# x = x + ffn(LayerNorm(x))
# ```
#
# Le `x +` est l'autoroute du gradient. La validation inclut le « test du résidu »,
# qui attrape un câblage Post-LN.

# %%
class TransformerBlock(nn.Module):
    """L'unité qu'on empile : attention + FFN, chacun avec Pre-LN et résidu."""

    def __init__(self, d_model, n_heads, d_ff):
        super().__init__()
        self.ln1 = nn.LayerNorm(d_model)
        self.attn = MultiHeadAttention(d_model, n_heads)
        self.ln2 = nn.LayerNorm(d_model)
        self.ffn = FeedForward(d_model, d_ff)

    def forward(self, x, mask=None):
        # TODO(toi) : les deux sous-couches, chacune en x = x + souscouche(LN(x))
        #   1. x = x + self.attn(self.ln1(x), mask)
        #   2. x = x + self.ffn(self.ln2(x))
        ...
        return x

# %%
torch.manual_seed(0)
bloc = TransformerBlock(d_model=96, n_heads=4, d_ff=384)
x_test = torch.randn(2, 10, 96)
masque_test = torch.tril(torch.ones(10, 10))

y_test = bloc(x_test, masque_test)
assert isinstance(y_test, torch.Tensor), "remplace le ... par ton code"
assert y_test.shape == x_test.shape, "un bloc préserve la shape : c'est ce qui permet d'empiler"
assert not torch.allclose(y_test, x_test), "le bloc doit transformer x, pas le renvoyer tel quel"

# Le test du résidu : on éteint les deux sous-couches (dernières projections à zéro).
# Si ton câblage est bien x + souscouche(LN(x)), le bloc doit laisser passer x INTACT.
# (En Post-LN, x = LN(x + souscouche(x)), il sortirait LN(x), pas x.)
with torch.no_grad():
    bloc.attn.W_O.weight.zero_()
    bloc.ffn.net[2].weight.zero_()
    bloc.ffn.net[2].bias.zero_()
assert torch.allclose(bloc(x_test, masque_test), x_test, atol=1e-6), (
    "sous-couches éteintes, le bloc doit rendre x intact : vérifie tes résidus et le Pre-LN"
)
print("Exercice 4 validé : ton bloc transforme, préserve la shape, et l'autoroute résiduelle est en place.")

# %% [markdown]
# ### Exercice 5 · Le GPT complet — niveau ●●
#
# Trois étages dans le `forward` : les embeddings (tokens + positions, additionnés), la
# pile de blocs (chacun avec `self.masque`), puis la tête de sortie
# (`self.tete(self.ln_final(h))`). La validation vérifie le nombre de paramètres, la
# shape de sortie, et surtout la causalité : le passé ne doit pas voir le futur.

# %%
class GPT(nn.Module):
    """Embeddings + positions -> n_layers blocs -> LayerNorm -> tête de sortie."""

    def __init__(self):
        super().__init__()
        self.table_tokens = nn.Embedding(vocab_size, d_model)
        self.table_positions = nn.Embedding(block_size, d_model)
        self.blocs = nn.ModuleList(
            [TransformerBlock(d_model, n_heads, d_ff) for _ in range(n_layers)]
        )
        self.ln_final = nn.LayerNorm(d_model)
        self.tete = nn.Linear(d_model, vocab_size, bias=False)
        self.register_buffer("masque", torch.tril(torch.ones(block_size, block_size)))

    def forward(self, x):
        B, T = x.shape
        # TODO(toi) :
        #   1. h = self.table_tokens(x) + self.table_positions(torch.arange(T))
        #   2. passe h dans chaque bloc (avec self.masque)
        #   3. return self.tete(self.ln_final(h))
        ...

# %%
torch.manual_seed(42)
gpt_ex = GPT()
n_params_ex = sum(p.numel() for p in gpt_ex.parameters())
assert n_params_ex == 244_800, f"{n_params_ex} paramètres au lieu de 244 800 : relis les hyperparamètres"

x_ex, _ = fabriquer_batch(taille=4)
logits_ex = gpt_ex(x_ex)
assert logits_ex is not None and isinstance(logits_ex, torch.Tensor), "remplace le ... par ton code"
assert logits_ex.shape == (4, block_size, vocab_size), f"shape {tuple(logits_ex.shape)} au lieu de (4, 64, 81)"

# Le test de causalité : changer le DERNIER caractère ne doit rien changer aux
# prédictions des positions précédentes (le passé ne voit pas le futur).
x2_ex = x_ex.clone()
x2_ex[:, -1] = (x2_ex[:, -1] + 1) % vocab_size
logits2_ex = gpt_ex(x2_ex)
assert torch.allclose(logits_ex[:, :-1], logits2_ex[:, :-1], atol=1e-5), (
    "changer le futur change le passé : le masque causal n'est pas branché"
)
assert not torch.allclose(logits_ex[:, -1], logits2_ex[:, -1]), "la dernière position devrait, elle, changer"
print("Exercice 5 validé : ton GPT sort un score par caractère et par position, et respecte la causalité.")

# %% [markdown]
# ### Exercice 6 · La génération — niveau ●●
#
# La même mécanique qu'au chapitre 1 : prédire des probabilités, tirer au sort, décaler
# le contexte, recommencer. Seule différence : le GPT rend un score par position, et
# seul le DERNIER pas nous intéresse pour prédire la suite (`logits[:, -1, :]`).
# Quatre lignes dans la boucle.

# %%
def generer(model, prompt="\n", longueur=300, temperature=0.8):
    """Écrit `longueur` caractères à la suite de `prompt`, avec le GPT."""
    model.eval()
    ctx = ([stoi["\n"]] * block_size + [stoi[c] for c in prompt])[-block_size:]
    sortie = []
    with torch.no_grad():
        for _ in range(longueur):
            # TODO(toi) :
            #   1. logits = model(torch.tensor([ctx]))[:, -1, :]     le dernier pas seulement
            #   2. probas = torch.softmax(logits / temperature, dim=-1)
            #   3. i = torch.multinomial(probas, num_samples=1).item()
            #   4. ajoute itos[i] à sortie, puis ctx = ctx[1:] + [i]
            ...
    return prompt + "".join(sortie)

# %%
torch.manual_seed(7)
texte = generer(gpt, prompt="La cigale", longueur=80)
assert isinstance(texte, str) and texte.startswith("La cigale"), "le texte doit commencer par le prompt"
assert len(texte) == len("La cigale") + 80, f"longueur {len(texte)} au lieu de {len('La cigale') + 80}"
assert set(texte) <= set(chars), "tous les caractères générés doivent venir du vocabulaire"
print("Exercice 6 validé : ton GPT écrit.")

# %% [markdown]
# ### Exercice 7 · La classe `MultiHeadAttention` — niveau ●●●
#
# Le morceau de bravoure : tout le chapitre 9, plus le découpage en têtes. Le forward,
# en cinq gestes :
#
# 1. projeter `x` en Q, K, V (trois `nn.Linear`), puis découper chacun en têtes ;
# 2. scores : `Q @ K.transpose(-2, -1) / math.sqrt(d_k)` ;
# 3. masque causal (s'il est fourni) : `-inf` sur le futur, AVANT le softmax ;
# 4. softmax ligne par ligne, puis moyenne pondérée des values ;
# 5. recoller les têtes (`transpose(1, 2).contiguous().view(B, T, d_model)`) et projeter par `W_O`.
#
# La validation compare ta sortie à `nn.MultiheadAttention`, l'implémentation
# officielle de PyTorch, à 10⁻⁵ près.

# %%
class MultiHeadAttention(nn.Module):
    """n_heads attentions en parallèle dans des sous-espaces de dimension d_k."""

    def __init__(self, d_model, n_heads):
        super().__init__()
        assert d_model % n_heads == 0, "d_model doit être divisible par n_heads"
        self.n_heads = n_heads
        self.d_k = d_model // n_heads
        self.W_Q = nn.Linear(d_model, d_model, bias=False)
        self.W_K = nn.Linear(d_model, d_model, bias=False)
        self.W_V = nn.Linear(d_model, d_model, bias=False)
        self.W_O = nn.Linear(d_model, d_model, bias=False)   # mixe les têtes recollées

    def forward(self, x, mask=None):
        B, T, d_model = x.shape
        # TODO(toi) :
        #   1. Q = decouper_en_tetes(self.W_Q(x), self.n_heads)   idem K, V
        #   2. scores = Q @ K.transpose(-2, -1) / math.sqrt(self.d_k)
        #   3. si mask n'est pas None : scores = scores.masked_fill(mask[:T, :T] == 0, float('-inf'))
        #   4. poids = torch.softmax(scores, dim=-1) ; melange = poids @ V
        #   5. out = melange.transpose(1, 2).contiguous().view(B, T, d_model) ; return self.W_O(out)
        ...

# %%
# Validation contre l'implémentation officielle de PyTorch : on copie les poids
# de nn.MultiheadAttention dans ta classe, et les sorties doivent coïncider.
torch.manual_seed(0)
d_test, h_test, T_test = 32, 4, 7

reference = nn.MultiheadAttention(d_test, h_test, bias=False, batch_first=True)
mienne = MultiHeadAttention(d_test, h_test)
with torch.no_grad():
    Wq, Wk, Wv = reference.in_proj_weight.chunk(3, dim=0)
    mienne.W_Q.weight.copy_(Wq)
    mienne.W_K.weight.copy_(Wk)
    mienne.W_V.weight.copy_(Wv)
    mienne.W_O.weight.copy_(reference.out_proj.weight)

x_test = torch.randn(2, T_test, d_test)
interdit = torch.triu(torch.ones(T_test, T_test, dtype=torch.bool), diagonal=1)
sortie_ref, _ = reference(x_test, x_test, x_test, attn_mask=interdit, need_weights=False)
sortie_mienne = mienne(x_test, mask=torch.tril(torch.ones(T_test, T_test)))

assert sortie_mienne is not None and isinstance(sortie_mienne, torch.Tensor), "remplace le ... par ton code"
assert sortie_mienne.shape == (2, T_test, d_test), f"shape {tuple(sortie_mienne.shape)}"
assert torch.allclose(sortie_ref, sortie_mienne, atol=1e-5), (
    "ta sortie diffère de nn.MultiheadAttention : vérifie le découpage en têtes, "
    "le masque (avant le softmax !) et le recollage"
)
print("Exercice 7 validé : ta MultiHeadAttention colle à nn.MultiheadAttention de PyTorch.")

# %% [markdown]
# ## Où en est notre LLM ?
#
# Fin de la Partie II. Tu viens d'assembler et d'entraîner, de tes mains :
#
# - le **multi-head attention** (le découpage en têtes, le recollage, la projection W_O) ;
# - les **embeddings de positions**, parce que l'attention est aveugle à l'ordre ;
# - le **bloc Transformer** : Pre-LN, résidus, FFN, et la preuve expérimentale que
#   sans stabilisateurs, une pile profonde n'apprend pas ;
# - le **GPT complet** : 244 800 paramètres qui écrivent du pseudo-La Fontaine
#   nettement mieux que le MiniLM du chapitre 1.
#
# C'est la même architecture que GPT-2, à la taille près. La Partie III t'apprend à
# l'entraîner comme un labo : les vrais réglages (ch. 11), survivre à Colab (ch. 12),
# les données (ch. 13), les coûts (ch. 14), l'échelle (ch. 15), l'évaluation (ch. 16).
